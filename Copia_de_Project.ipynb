# %% [markdown]
# <a href="https://colab.research.google.com/github/glenda2912/Tous12/blob/main/Copia_de_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Project 1:**

# %% [markdown]
# # 1. Variables:

# %% [markdown]
#   ### **1.1 Name of description.**
#
#   *Femicides in Latin America*
#
#   **Description:** Violence against women in Latin America, number of femicides by country

# %% [markdown]
#  **1.2 Period or dates. Frequency. Individuals.**
#
#
# 1.   Period: 2017-2021.
# 2.   Frequency: Annual.
# 3.   Individuals: Brasil, Colombia,    Honduras and Mexico.
#
# **Selection of the countries:**
#
# I chose these 5 countries out of 22 because they are the ones showing an increase in femicides over the years and  the statistical graph shows that the number of femicides has been increasing from 2017 to 2021.

# %% [markdown]
#  **1.3 Sources**
#
#    * [CEPALSTAT](https://statistics.cepal.org/portal/cepalstat/dashboard.html?lang=es) 👥
#  * [Honduras](https://www.globalcitizen.org/en/content/honduras-femicide-red-alert/)
#  * [Brazil](https://womensmediacenter.com/women-under-siege/while-murder-rates-fall-in-brazil-femicide-remains-on-the-rise)
#  * [Mexico](https://www.unwomen.org/en/news/stories/2017/11/feature-prosecuting-femicide-in-mexico)
#  * [Colombia](https://insightcrime.org/investigations/feminicides-tibu-colombia-cocaine-gunmen-never-ending-war/)

# %% [markdown]
# # 2. Goal of the DV

# %% [markdown]
# ### 2.1 Story
#  Femicides in latin america from 2017 to 2021, the country with the highest number of femicides was brazil and I was impressed by the number of women who have died in that country, it is extremely high compared to other countries, not only I want to know the number but the reasons and why it is still increasing more and more and so with the different countries that were chosen for the study.

# %% [markdown]
# ### 2.2 Audience
#
#  The audience that would be interested in the **dv** would be a general audience.
#
#  It is important that people recognize the reasons and the number of femicides in latin america.

# %% [markdown]
# ### 2.3 Justify the DV type
#
#  **Dv** : I would like to use Stacked Bars because it would select the countries and the number of femicides orderly and structured way.
#
#  ![Captura de pantalla 2023-03-02 000554.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Examples:

# %% [markdown]
# ### 3.1 Example A
# *Description*:
#
# ![Captura de pantalla 2023-03-02 003320.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.2 Example B
#
#
#
#
# ![Captura de pantalla 2023-03-02 004430.png](data:image/png;base64,...)
