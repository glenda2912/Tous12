# %% [markdown]
# <a href="https://colab.research.google.com/github/glenda2912/Tous12/blob/main/Feminicides_(exam_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**1.Intro**

# %%
# Libraries

import numpy as np
import pandas as pd

# %% [markdown]
# ##**2.Import**

# %%
# Save the path o the file 

p= '/content/fm.xlsx'

#Read the file 
d = pd.read_excel(p)


#Check
d.info()

# %%
#Check the fist entries
d.head()
# Out:
#    Year   Country  Value
# 0  2017    Brasil   1582
# 1  2017      Perú    116
# 2  2017  Honduras    235
# 3  2017    México    742
# 4  2018    México    893

# %%
#Check the last entries 
d.tail()
# Out:
#     Year   Country  Value
# 20  2021    Brasil   1900
# 21  2021  Colombia    210
# 22  2021  Honduras    234
# 23  2021    México   1015
# 24  2021      Perú    136

# %% [markdown]
# # **3.Cleaning**

# %% [markdown]
# ## Column Names

# %%
# Change Time for Year 
d.rename(columns = {"Años": "Year"}, inplace = True)

# Change County Name
d.rename(columns = {"País": "Country"}, inplace = True)

#Change Value
d.rename(columns = {"Value": "Hom"}, inplace = True)

#Check
d.head()
# Out:
#    Year   Country   Hom
# 0  2017    Brasil  1582
# 1  2017      Perú   116
# 2  2017  Honduras   235
# 3  2017    México   742
# 4  2018    México   893

# %% [markdown]
# ## Delete columns
#
# **My data base is so short so i'm not going to delete the column**

# %% [markdown]
# ## A few more things

# %%
# (Optional) Duplicate the dataframe

pp = d

# %%
# Duplicate year variable 
pp["Year_str"] = pp["Year"].astype(str)

#Check
pp.head()
# Out:
#    Year   Country   Hom Year_str
# 0  2017    Brasil  1582     2017
# 1  2017      Perú   116     2017
# 2  2017  Honduras   235     2017
# 3  2017    México   742     2017
# 4  2018    México   893     2018
